# %% [markdown]
# <a href="https://colab.research.google.com/github/Meena-27/uber-trips-analysis/blob/main/uber_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#To read the dataset
import pandas as pd

#For visualization
import matplotlib.pyplot as plt

# %%
#Read the dataset
uber_df= pd.read_csv("/content/uber-raw-data-sep14.csv")

#Display the first 5 records
uber_df.head(5)
# Out:
#           Date/Time      Lat      Lon    Base
# 0  9/1/2014 0:01:00  40.2201 -74.0021  B02512
# 1  9/1/2014 0:01:00  40.7500 -74.0027  B02512
# 2  9/1/2014 0:03:00  40.7559 -73.9864  B02512
# 3  9/1/2014 0:06:00  40.7450 -73.9889  B02512
# 4  9/1/2014 0:11:00  40.8145 -73.9444  B02512

# %%
uber_df.tail()
# Out:
#               Date/Time      Lat      Lon    Base
# 91588  9/8/2014 7:36:00  40.6821 -73.9346  B02598
# 91589  9/8/2014 7:36:00  40.7684 -73.9169  B02598
# 91590  9/8/2014 7:36:00  40.7726 -73.9469  B02598
# 91591  9/8/2014 7:36:00  40.7147 -73.9639  B02598
# 91592  9/8/2014 7:36:00      NaN      NaN     NaN

# %%
#Find the shape of the dataset
uber_df.shape
# Out:
# (91593, 4)

# %%
uber_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91593 entries, 0 to 91592
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date/Time  91593 non-null  object
#  1   Lat        91592 non-null  float64
#  2   Lon        91592 non-null  float64
#  3   Base       91592 non-null  object
# dtypes: float64(2), object(2)
# memory usage: 2.8+ MB

# %%
uber_df['Date/Time']= pd.to_datetime(uber_df['Date/Time'])

#Convert "Date/Time" column from string data type into DateTime
uber_df["Day"] = uber_df["Date/Time"].apply(lambda x: x.day)
uber_df["Hour"] = uber_df["Date/Time"].apply(lambda x: x.hour)
uber_df["Weekday"] = uber_df["Date/Time"].apply(lambda x: x.weekday())
uber_df.head(5)
# Out:
#             Date/Time      Lat      Lon    Base  Day  Hour  Weekday
# 0 2014-09-01 00:01:00  40.2201 -74.0021  B02512    1     0        0
# 1 2014-09-01 00:01:00  40.7500 -74.0027  B02512    1     0        0
# 2 2014-09-01 00:03:00  40.7559 -73.9864  B02512    1     0        0
# 3 2014-09-01 00:06:00  40.7450 -73.9889  B02512    1     0        0
# 4 2014-09-01 00:11:00  40.8145 -73.9444  B02512    1     0        0

# %%
fig,ax = plt.subplots(figsize = (12,6))
plt.hist(uber_df.Day, width= 0.6, bins= 30,color="pink")
plt.title("Density of trips per Day", fontsize=16)
plt.xlabel("Day", fontsize=14)
plt.ylabel("Density of rides", fontsize=14)
# Out:
# Text(0, 0.5, 'Density of rides')

# %%
fig,ax = plt.subplots(figsize = (12,6))
plt.hist(uber_df.Weekday, width= 0.6, range= (0, 6.5), bins=7, color= "orange")
plt.title("Density of trips per Weekday", fontsize=16)
plt.xlabel("Weekday", fontsize=14)
plt.ylabel("Density of rides", fontsize=14)
# Out:
# Text(0, 0.5, 'Density of rides')

# %%
#Visualize the Density of rides per hour
fig,ax = plt.subplots(figsize = (12,6))
plt.hist(uber_df.Hour, width= 0.6, bins=24, color= "purple")
plt.title("Density of trips per Hour", fontsize=16)
plt.xlabel("Hour", fontsize=14)
plt.ylabel("Density of rides", fontsize=14)
# Out:
# Text(0, 0.5, 'Density of rides')

# %%
#Visualize the Density of rides per location
fig,ax = plt.subplots(figsize = (12,6))
x= uber_df.Lon
y= uber_df.Lat
plt.scatter(x, y, color= "lavender")
plt.title("Density of trips per Hour", fontsize=16)
plt.xlabel("Hour", fontsize=14)
plt.ylabel("Density of rides", fontsize=14)
# Out:
# Text(0, 0.5, 'Density of rides')

# %% [markdown]
# #### The region with the highest density of rides is near Manhattan and Newburgh. While the region with the lowest density is near New Jersey.
